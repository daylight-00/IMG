# %%
script_path = 'code'                    # 실제 script 경로로 변경
config_path = 'config_demo_dn.py'       # 실제 config 파일 경로로 변경
# config_path = 'config_demo_esm.py'     # 실제 config 파일 경로로 변경

import sys, os
utils_path = os.path.abspath(script_path)
sys.path.insert(0, utils_path)

# %%
from train import main as train
train(config_path)
# Out:
# Number of HLA alleles: 7044
# Number of samples: 238429
# Total samples: 238429
# Samples in train set: 190743
# Samples in validation set: 47686
# Model loaded on cuda
# Epoch 1/100:   8%|▊         | 15/187 [00:02<00:20,  8.44batch/s, loss=0.562]

# %%
from test import main as test
test(config_path)
# Out:
# Model loaded on cuda
# Number of HLA alleles: 7044
# Number of samples: 102180
# Samples in test set: 102180
# Testing: 100%|██████████| 100/100 [00:06<00:00, 15.86it/s]
# ROC curve saved as plots/roc_curve-deepneo.png
#
# Samples in test set for HLAA0201: 9287
# Testing: 100%|██████████| 10/10 [00:01<00:00,  7.11it/s]
# Samples in test set for HLAB2705: 3368
# Testing: 100%|██████████| 4/4 [00:00<00:00,  4.68it/s]
# Samples in test set for HLAB1502: 2968
# Testing: 100%|██████████| 3/3 [00:00<00:00,  3.54it/s]
# Samples in test set for HLAB1501: 2607
# Testing: 100%|██████████| 3/3 [00:00<00:00,  3.66it/s]
# Samples in test set for HLAB5101: 2425
# Testing: 100%|██████████| 3/3 [00:00<00:00,  3.62it/s]
# Samples in test set for HLAA1101: 2375
# Testing: 100%|██████████| 3/3 [00:00<00:00,  3.64it/s]
# Samples in test set for HLAB0702: 2339
# Testing: 100%|██████████| 3/3 [00:00<00:00,  3.64it/s]
# Samples in test set for HLAB4001: 2332
# ...

# %%
import utils.loss_plot as loss_plot
loss_plot.main(config_path)
# Out:
# Loss plot saved as plots/loss_plot-deepneo.png
